# %% [markdown]
# # Lab2 - Exercises
# Finish the following program exercises and short question

# %% [markdown]
# ## Exercise 1: ICA on 4-channel speech audio
#
# Unzip the `exer1_data` zip file according to your student ID and stack all audios into one. Use `FastICA` to separate them. Compute the metrics SDR, SIR, SAR. Plot each separated signal and its spectrogram (use `plt.subplot()`)

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: RPCA with different set of parameters
#
# Load the music `xxx.mp3` **at its original sample rate** for **5 seconds** and use RPCA to separate it by trying different combination of parameters `nFFT` and `hopLength`. You can refer to the tabel below
# - Complete the full programs
# - Display the separated sources and compute the metrics SDR, SIR, and SAR for each combination
# - Fill in these value in the table below by editting the markdown editor
#
# | nFFT     | hopLength | SDR | SIR | SAR |
# |----------|-----------|-----|-----|-----|
# | 1024     | 256       |     |     |     |
# | 2048     | 512       |     |     |     |
# | 2048     | 1024      |     |     |     |
# | 4096     | 1024      |     |     |     |
# | 4096     | 2048      |     |     |     |

# %%
# Your code here

# %% [markdown]
# Discuss how different `nFFT` and `hopLength` affect the performance

# %% [markdown]
# Given the `nFFT=2048`, and `hopLength=256`. Try different values of `lmbda` between `0.5` to `2.0` and find a lmbda value that can get SDR, SIR, and SAR greater than `36`

# %%
# Your code here
nFFT = 2048
hopLength = 256
lmbda = 0.5

# %% [markdown]
# Discuss how different values of `lmbda` affects the performance

# %% [markdown]
# ## Exercise3: Conv-TasNet
#
# Apply `Conv-TasNet` on the audio `./Dataset/RPCA/music_sample5.mp3`. Compute the SDR, SIR, and SAR. Display the separated sounds and plot their spectrogram

# %%
# Your code here
