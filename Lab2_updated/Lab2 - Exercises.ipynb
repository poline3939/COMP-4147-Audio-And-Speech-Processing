# %% [markdown]
# # Lab2 - Exercises
# Finish the following program exercises and short question
#
# > Note: Refer to the document `Practical Assignment 2 Guidelines.pdf` to know which subset of dataset you should use in the following tasks

# %% [markdown]
# ## Task 1: ICA on 4-channel speech audio
#
# > Provided data: `exer1_A.zip` / `exer1_B.zip`
#
# Unzip the zip file according to your student ID and mix all audios into one at a sample rate **8 kHz**. Use `FastICA` to separate them. Display the separated audios. Compute the metrics SDR, SIR, SAR. Plot each separated signal and its spectrogram (use `plt.subplot()`)

# %%
# Your code here

# %% [markdown]
# ## Task 2: RPCA with different set of parameters
#
# > Provided data: `music_A.mp3` / `music_B.mp3`
#
# Load the provided music **at its original sample rate** for **5 seconds** and use RPCA to separate it by trying different combination of parameters `nFFT` and `hopLength`. You can refer to the tabel below
# - Complete the full programs
# - Display the separated sources and compute the metrics SDR, SIR, and SAR for each combination
# - Fill in these value in the table below by editting the markdown editor
#
# | nFFT     | hopLength | SDR | SIR | SAR |
# |----------|-----------|-----|-----|-----|
# | 1024     | 256       |     |     |     |
# | 2048     | 512       |     |     |     |
# | 2048     | 1024      |     |     |     |
# | 4096     | 1024      |     |     |     |
# | 4096     | 2048      |     |     |     |

# %%
# Your code here

# %% [markdown]
# Discuss how different `nFFT` and `hopLength` affect the performance

# %% [markdown]
# Given the `nFFT=2048`, and `hopLength=256`. Try different values of `lmbda` between `0.5` to `2.0` and find a lmbda value that can get SDR, SIR, and SAR greater than `50`

# %%
# Your code here
nFFT = 2048
hopLength = 256
lmbda = 0.5

# %% [markdown]
# Discuss how different values of `lmbda` affects the performance

# %% [markdown]
# ## Task 3: Conv-TasNet
#
# > Provided data: `exer3_A.wav` / `exer3_B.wav`
#
# Apply the pre-trained `Conv-TasNet` on the provided audio. Compute the SDR, SIR, and SAR. Display the separated signals and plot their spectrogram

# %%
import torch
from torchaudio.pipelines import CONVTASNET_BASE_LIBRI2MIX

# Your code here

# %% [markdown]
# Download the notebook `Lab2 - TasNet.ipynb` and complete the task in the notebook

# %% [markdown]
# ## Task 4: DPRNN
#
# > Provided data: `noise_A.wav` / `noise_B.wav`
#
# Record your own voice by reading the the following content:
#
# *"Hello, how are you. I am fine, thank you. I love audio processing"*
#
# Following the guideline below to finish the task

# %% [markdown]
# First download the package `sounddevice`

# %%
# !pip install sounddevice

# %% [markdown]
# Uncomment the following code snippet to record and save the audio locally

# %%
# import sounddevice as sd
# from scipy.io.wavfile import write

# fs = 16000
# seconds = 5
# audio_name = "myvoice.wav"

# print("Recording...")
# my_audio = sd.rec(int(seconds * fs), samplerate=fs, channels=1, dtype='float32')
# sd.wait()
# print("Recording complete.")

# write(audio_name, fs, my_audio)
# print(f"Saved as {audio_name}")

# %% [markdown]
# Mix the saved audio with the priveded noise (`noise_A.wav` or `noise_B.wav`) in mono at a sample rate **16 kHz** and display the mixed audio

# %%
# Your code here

# %% [markdown]
# Load the pre-trained model `JorisCos/DPRNNTasNet-ks2_Libri1Mix_enhsingle_16k`, which is available on Hugging Face for **single-speaker speech enhancement** using the **Libri1Mix** dataset sampled at 16 kHz. Then separate your voice out of the mixed noisy audio using the loaded model

# %%
# Your code here

# %% [markdown]
# Compare the spectrograms of mixed audio and separated audio

# %%
# Your code here

# %% [markdown]
# ## Submission
#
# Submit this ipynb notebook to Moodle before xxxx
